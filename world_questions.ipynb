# %%
# !pip install sqlalchemy
# Out:
# Requirement already satisfied: sqlalchemy in /home/daniel/datavenv/lib/python3.12/site-packages (2.0.38)
# Requirement already satisfied: greenlet!=0.4.17 in /home/daniel/datavenv/lib/python3.12/site-packages (from sqlalchemy) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in /home/daniel/datavenv/lib/python3.12/site-packages (from sqlalchemy) (4.12.2)

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
def create_sqlalchemy_engine():
    # Database connection parameters
    db_username = 'mysqluser'
    db_password = 'mysqluser_pass'
    db_host = 'ovh'
    db_port = '3300'
    db_name = 'world'

    # Create the SQLAlchemy engine
    engine = create_engine(f'mysql+pymysql://{db_username}:{db_password}@{db_host}:{db_port}/{db_name}')

    return engine

# %%
engine = create_sqlalchemy_engine()

# %% [markdown]
# ## ERD

# %% [markdown]
# ![World Database ERD](world_db_ERD.png)

# %% [markdown]
# ## Easy Level

# %% [markdown]
# ### 1. List all countries and their respective continents.

# %%
query = 'select name, continent from country order by continent;'
pd.read_sql(query, con=engine)
# Out:
#                      name      continent
# 0             Afghanistan           Asia
# 1    United Arab Emirates           Asia
# 2                 Armenia           Asia
# 3              Azerbaijan           Asia
# 4              Bangladesh           Asia
# ..                    ...            ...
# 234                  Peru  South America
# 235              Paraguay  South America
# 236              Suriname  South America
# 237               Uruguay  South America
# 238             Venezuela  South America
#
# [239 rows x 2 columns]

# %% [markdown]
# ### 2. Retrieve all cities and their corresponding countries.

# %%
query = '''
select
    city.name as city,
    country.name as country
from city
join country on city.countrycode = country.code
order by country ;'''

pd.read_sql(query, con=engine)
# Out:
#                 city      country
# 0              Kabul  Afghanistan
# 1           Qandahar  Afghanistan
# 2              Herat  Afghanistan
# 3     Mazar-e-Sharif  Afghanistan
# 4             Tirana      Albania
# ...              ...          ...
# 4074        Bulawayo     Zimbabwe
# 4075     Chitungwiza     Zimbabwe
# 4076    Mount Darwin     Zimbabwe
# 4077          Mutare     Zimbabwe
# 4078           Gweru     Zimbabwe
#
# [4079 rows x 2 columns]

# %% [markdown]
# ### 3. Find all distinct continents in the database.

# %%
query = 'select distinct continent from country order by 1;'
pd.read_sql(query, con=engine)
# Out:
#        continent
# 0           Asia
# 1         Europe
# 2  North America
# 3         Africa
# 4        Oceania
# 5     Antarctica
# 6  South America

# %% [markdown]
# ### 4. Count the number of countries in the database.

# %%
query = 'select count(distinct name) as number_countries from country ;'
pd.read_sql(query, con=engine)
# Out:
#    number_countries
# 0               239

# %% [markdown]
# ### 5. Retrieve the population of 'Canada'.

# %%
query = '''
select name, population
from country
where name = 'Canada' ;'''
pd.read_sql(query, con=engine)
# Out:
#      name  population
# 0  Canada    31147000

# %% [markdown]
# ### 6. Find the official language spoken in 'Germany'.

# %%
query = '''
select language, 'Germany' as country
from countrylanguage
where isofficial = 'T'
and countrycode = (select code from country where name = 'Germany') ;'''
pd.read_sql(query, con=engine)
# Out:
#   language  country
# 0   German  Germany

# %% [markdown]
# ### 7. List all cities in 'France' along with their populations.

# %%
query = '''
select city.name as city, country.population as population
from city
join country on city.countrycode = country.code
where country.name = 'France'
order by population desc ; '''
pd.read_sql(query, con=engine)
# Out:
#                     city  population
# 0                  Paris    59225700
# 1              Marseille    59225700
# 2                   Lyon    59225700
# 3               Toulouse    59225700
# 4                   Nice    59225700
# 5                 Nantes    59225700
# 6             Strasbourg    59225700
# 7            Montpellier    59225700
# 8               Bordeaux    59225700
# 9                 Rennes    59225700
# 10              Le Havre    59225700
# 11                 Reims    59225700
# 12                 Lille    59225700
# 13            St-Étienne    59225700
# 14                Toulon    59225700
# 15              Grenoble    59225700
# 16                Angers    59225700
# 17                 Dijon    59225700
# 18                 Brest    59225700
# 19               Le Mans    59225700
# 20      Clermont-Ferrand    59225700
# 21                Amiens    59225700
# 22       Aix-en-Provence    59225700
# 23               Limoges    59225700
# 24                 Nîmes    59225700
# 25                 Tours    59225700
# 26          Villeurbanne    59225700
# 27                  Metz    59225700
# 28              Besançon    59225700
# 29                  Caen    59225700
# 30               Orléans    59225700
# 31              Mulhouse    59225700
# 32                 Rouen    59225700
# 33  Boulogne-Billancourt    59225700
# 34             Perpignan    59225700
# 35                 Nancy    59225700
# 36               Roubaix    59225700
# 37            Argenteuil    59225700
# 38             Tourcoing    59225700
# 39             Montreuil    59225700

# %% [markdown]
# ### 8. Retrieve all country codes and their respective names.

# %%
query = 'select name as country, code from country order by 2 ;'
pd.read_sql(query, con=engine)
# Out:
#           country code
# 0           Aruba  ABW
# 1     Afghanistan  AFG
# 2          Angola  AGO
# 3        Anguilla  AIA
# 4         Albania  ALB
# ..            ...  ...
# 234         Yemen  YEM
# 235    Yugoslavia  YUG
# 236  South Africa  ZAF
# 237        Zambia  ZMB
# 238      Zimbabwe  ZWE
#
# [239 rows x 2 columns]

# %% [markdown]
# ### 9. Display the total population of all countries combined.

# %%
query = 'select sum(population) as total_pop from country ;'
pd.read_sql(query, con=engine)
# Out:
#       total_pop
# 0  6.078749e+09

# %% [markdown]
# ### 10. Find the largest city in 'USA'.

# %%
query = '''
select name as city,
population
from city
where countrycode = (
    select code from country
    where name = 'United States'
    )
order by population desc
limit 1 ;'''
pd.read_sql(query, con=engine)
# Out:
#        city  population
# 0  New York     8008278
